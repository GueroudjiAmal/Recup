# %% [markdown]
# Image Processing
# ================

# %% [markdown]
# Welcome to the quickstart guide for dask-image.

# %% [markdown]
# 1. [Setting up your environment](#Setting-up-your-environment)
# 1. [Importing dask-image](#Importing-dask-image)
# 1. [Getting the example data](#Getting-the-example-data)
# 1. [Reading in image data](#Reading-in-image-data)
#     1. [Reading a single image](#Reading-a-single-image)
#     1. [Reading multiple images](#Reading-multiple-images)
#
# 1. [Applying your own custom function to images](#Applying-your-own-custom-function-to-images)
#     1. [Embarrassingly parallel problems](#Embarrassingly-parallel-problems)
#
# 1. [Joining partial images together](#Joining-partial-images-together)
#
# 1. [A segmentation analysis pipeline](#A-segmentation-analysis-pipeline)
#     1. [Filtering](#Filtering)
#     1. [Segmenting](#Segmenting)
#     1. [Analyzing](#Analyzing)
# 1. [Next steps](#Next-steps)
# 1. [Cleaning up temporary directories and files](#Cleaning-up-temporary-directories-and-files)

# %% [markdown]
# ## [Setting up your environment](#Setting-up-your-environment)

# %% [markdown]
# ### Install Extra Dependencies
#
# We first install the library scikit-image for easier access to the example image data there.

# %% [markdown]
# If you are running this notebook on your own computer and not in the mybinder environment, you'll additionally need to ensure your Python environment contains:
# * dask
# * dask-image
# * python-graphviz
# * scikit-image
# * matplotlib
# * numpy
#
# You can refer to the full list of dependencies used for the `dask-examples` repository, available in the [`binder/environment.yml` file here](https://github.com/dask/dask-examples/blob/main/binder/environment.yml
# ) (note that the `nomkl` package is not available for Windows users): https://github.com/dask/dask-examples/blob/main/binder/environment.yml

# %% [markdown]
# ## [Importing dask-image](#Importing-dask-image)

# %% [markdown]
# When you import dask-image, be sure to use an underscore instead of a dash between the two words.

# %%
import dask_image.imread
import dask_image.ndfilters
import dask_image.ndmeasure
import dask.array as da

# %% [markdown]
# We'll also use matplotlib to display image results in this notebook.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Use the distributed scheduler rather than local dask 
from distributed import Client
# Creating a local cluster
client = Client()
# Out:
# distributed.diskutils - INFO - Found stale lock file and directory '/home/agueroudji/recup/dask-worker-space/worker-mi7wdd5n', purging
# distributed.diskutils - INFO - Found stale lock file and directory '/home/agueroudji/recup/dask-worker-space/worker-9n6rx2pi', purging

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:41349' processes=4 threads=12, memory=31.00 GiB>

# %% [markdown]
# ## [Getting the example data](#Getting-the-example-data)

# %% [markdown]
# We'll use some example image data from the scikit-image library in this tutorial. These images are very small, but will allow us to demonstrate the functionality of dask-image.
#
# Let's download and save a public domain image of the astronaut Eileen Collins to a temporary directory. This image was originally downloaded from the NASA Great Images database <https://flic.kr/p/r9qvLn>, but we'll access it with scikit-image's `data.astronaut()` method.

# %%
# !mkdir temp

# %%
import os
from skimage import data, io

output_filename = os.path.join('temp', 'astronaut.png')
io.imsave(output_filename, data.astronaut())

# %% [markdown]
# Really large datasets often can't fit all of the data into a single file, so we'll chop this image into four parts and save the image tiles to a second temporary directory. This will give you a better idea of how you can use dask-image on a real dataset.

# %%
# !mkdir temp-tiles

# %%
io.imsave(os.path.join('temp-tiles', 'image-00.png'), data.astronaut()[:256, :256, :])  # top left
io.imsave(os.path.join('temp-tiles', 'image-01.png'), data.astronaut()[:256, 256:, :])  # top right
io.imsave(os.path.join('temp-tiles', 'image-10.png'), data.astronaut()[256:, :256, :])  # bottom left
io.imsave(os.path.join('temp-tiles', 'image-11.png'), data.astronaut()[256:, 256:, :])  # bottom right

# %% [markdown]
# Now we have some data saved, let's practise reading in files with dask-image and processing our images.

# %% [markdown]
# ## [Reading in image data](#Reading-in-image-data)

# %% [markdown]
# ### [Reading a single image](#Reading-a-single-image)

# %% [markdown]
# Let's load a public domain image of the astronaut Eileen Collins with dask-image [imread()](http://image.dask.org/en/latest/dask_image.imread.html). This image was originally downloaded from the NASA Great Images database <https://flic.kr/p/r9qvLn>.

# %%
import os
filename = os.path.join('temp', 'astronaut.png')
print(filename)
# Out:
# temp/astronaut.png

# %%
astronaut = dask_image.imread.imread(filename)
print(astronaut)
plt.imshow(astronaut[0, ...])  # display the first (and only) frame of the image
# Out:
# dask.array<_map_read_frame, shape=(1, 512, 512, 3), dtype=uint8, chunksize=(1, 512, 512, 3), chunktype=numpy.ndarray>

# %% [markdown]
# This has created a dask array with `shape=(1, 512, 512, 3)`. This means it contains one image frame with 512 rows, 512 columns, and 3 color channels.
#
# Since the image is relatively small, it fits entirely within one dask-image chunk, with `chunksize=(1, 512, 512, 3)`.

# %% [markdown]
# ### [Reading multiple images](#Reading-multiple-images)

# %% [markdown]
# In many cases, you may have multiple images stored on disk, for example:
# `image_00.png`, `image_01.png`, ... `image_NN.png`. These can be read into a dask array as multiple image frames.

# %% [markdown]
# Here we have the astronaut image split into four non-overlapping tiles:
# * `image_00.png` = top left image (index 0,0)
# * `image_01.png` = top right image (index 0,1)
# * `image_10.png` = bottom left image (index 1,0)
# * `image_11.png` = bottom right image (index 1,1)
#
# This filename pattern can be matched with regex: `image-*.png`

# %%
# !ls temp-tiles
# Out:
# image-00.png  image-01.png  image-10.png  image-11.png

# %%
import os
filename_pattern = os.path.join('temp-tiles', 'image-*.png')
tiled_astronaut_images = dask_image.imread.imread(filename_pattern)
print(tiled_astronaut_images)
# Out:
# dask.array<_map_read_frame, shape=(4, 256, 256, 3), dtype=uint8, chunksize=(1, 256, 256, 3), chunktype=numpy.ndarray>

# %% [markdown]
# This has created a dask array with `shape=(4, 256, 256, 3)`. This means it contains four image frames; each with 256 rows, 256 columns, and 3 color channels.
#
# There are four chunks in this particular case. Each image frame here is a separate chunk with `chunksize=(1, 256, 256, 3)`.

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0,0].imshow(tiled_astronaut_images[0])
ax[0,1].imshow(tiled_astronaut_images[1])
ax[1,0].imshow(tiled_astronaut_images[2])
ax[1,1].imshow(tiled_astronaut_images[3])
plt.show()

# %% [markdown]
# ## [Applying your own custom function to images](#Applying-your-own-custom-function-to-images)

# %% [markdown]
# Next you'll want to do some image processing, and apply a function to your images.
#
# We'll use a very simple example: converting an RGB image to grayscale. But you can also use this method to apply arbittrary functions to dask images. To convert our image to grayscale, we'll use the equation to calculate luminance ([reference pdf](http://www.poynton.com/PDFs/ColorFAQ.pdf))":
#
# `Y = 0.2125 R + 0.7154 G + 0.0721 B`
#
# We'll write the function for this equation as follows:

# %%
def grayscale(rgb):
    result = ((rgb[..., 0] * 0.2125) + 
              (rgb[..., 1] * 0.7154) + 
              (rgb[..., 2] * 0.0721))
    return result

# %% [markdown]
# Let's apply this function to the astronaut image we read in as a single file and visualize the computation graph.
#
# (Visualizing the computation graph isn't necessary most of the time but it's helpful to know what dask is doing under the hood, and it can also be very useful for debugging problems.)

# %%
single_image_result = grayscale(astronaut)
print(single_image_result)
single_image_result.visualize()
# Out:
# dask.array<add, shape=(1, 512, 512), dtype=float64, chunksize=(1, 512, 512), chunktype=numpy.ndarray>

# %% [markdown]
# We also see that there are no longer three color channels in the shape of the result, and that the output image is as expected.

# %%
print("Original image dimensions: ", astronaut.shape)
print("Processed image dimensions:", single_image_result.shape)

fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2)
ax0.imshow(astronaut[0, ...])            # display the first (and only) frame of the image
ax1.imshow(single_image_result[0, ...], cmap='gray')  # display the first (and only) frame of the image

# Subplot headings
ax0.set_title('Original image')
ax1.set_title('Processed image')

# Don't display axes
ax0.axis('off')
ax1.axis('off')

# Display images
plt.show(fig)
# Out:
# Original image dimensions:  (1, 512, 512, 3)
# Processed image dimensions: (1, 512, 512)

# %% [markdown]
# ### [Embarrassingly parallel problems](#Embarrassingly-parallel-problems)

# %% [markdown]
# The syntax is identical to apply a function to multiple images or dask chunks. This is an example of an embarrassingly parallel problem, and we see that dask automatically creates a computation graph for each chunk.

# %%
result = grayscale(tiled_astronaut_images)
print(result)
result.visualize()
# Out:
# dask.array<add, shape=(4, 256, 256), dtype=float64, chunksize=(1, 256, 256), chunktype=numpy.ndarray>

# %% [markdown]
# Let's take a look at the results.

# %%
fig, ((ax0, ax1), (ax2, ax3)) = plt.subplots(nrows=2, ncols=2)
ax0.imshow(result[0, ...], cmap='gray')
ax1.imshow(result[1, ...], cmap='gray')
ax2.imshow(result[2, ...], cmap='gray')
ax3.imshow(result[3, ...], cmap='gray')

# Subplot headings
ax0.set_title('First chunk')
ax1.set_title('Second chunk')
ax2.set_title('Thurd chunk')
ax3.set_title('Fourth chunk')

# Don't display axes
ax0.axis('off')
ax1.axis('off')
ax2.axis('off')
ax3.axis('off')

# Display images
plt.show(fig)

# %% [markdown]
# ## [Joining partial images together](#Joining-partial-images-together)

# %% [markdown]
# OK, Things are looking pretty good! But how can we join these image chunks together?
#
# So far, we haven't needed any information from neighboring pixels to do our calculations. But there are lots of functions (like those in [dask-image ndfilters](https://dask-image.readthedocs.io/en/latest/dask_image.ndfilters.html)) that *do* need this for accurate results. You could end up with unwanted edge effects if you don't tell dask how your images should be joined.
#
# Dask has several ways to join chunks together: [Stack, Concatenate, and Block](http://docs.dask.org/en/latest/array-stack.html).

# %% [markdown]
# Block is very versatile, so we'll use that in this next example. You simply pass in a list (or list of lists) to tell dask the spatial relationship between image chunks.

# %%
data = [[result[0, ...], result[1, ...]],
        [result[2, ...], result[3, ...]]]
combined_image = da.block(data)
print(combined_image.shape)
plt.imshow(combined_image, cmap='gray')
# Out:
# (512, 512)

# %% [markdown]
# ## [A segmentation analysis pipeline](#A-segmentation-analysis-pipeline)

# %% [markdown]
# We'll walk through a simple image segmentation and analysis pipeline with three steps:
# 1. [Filtering](#Filtering)
# 1. [Segmenting](#Segmenting)
# 1. [Analyzing](#Analyzing)

# %% [markdown]
# ### [Filtering](#Filtering)

# %% [markdown]
# Most analysis pipelines require some degree of image preprocessing. dask-image has a number of inbuilt filters available via [dask-image ndfilters](https://dask-image.readthedocs.io/en/latest/dask_image.ndfilters.html)
#
# Commonly a guassian filter may used to smooth the image before segmentation. This causes some loss of sharpness in the image, but can improve segmentation quality for methods that rely on image thresholding.

# %%
smoothed_image = dask_image.ndfilters.gaussian_filter(combined_image, sigma=[1, 1])

# %% [markdown]
# We see a small amount of blur in the smoothed image.

# %%
fig, (ax0, ax1) = plt.subplots(nrows=1, ncols=2)
ax0.imshow(smoothed_image, cmap='gray')
ax1.imshow(smoothed_image - combined_image, cmap='gray')

# Subplot headings
ax0.set_title('Smoothed image')
ax1.set_title('Difference from original')

# Don't display axes
ax0.axis('off')
ax1.axis('off')

# Display images
plt.show(fig)

# %% [markdown]
# Since the gaussian filter uses information from neighbouring pixels, the computational graph looks more complicated than the ones we looked at earlier. This is no longer embarrassingly parallel. Where possible dask keeps the computations for each of the four image chunks separate, but must combine information from different chunks near the edges.

# %%
smoothed_image.visualize()

# %% [markdown]
# ### [Segmenting](#Segmenting)

# %% [markdown]
# After the image preprocessing, we segment regions of interest from the data. We'll use a simple arbitrary threshold as the cutoff, at 75% of the maximum intensity of the smoothed image.

# %%
threshold_value = 0.75 * da.max(smoothed_image).compute()
print(threshold_value)
# Out:
# 190.5550614819934

# %%
threshold_image = smoothed_image > threshold_value
plt.imshow(threshold_image, cmap='gray')

# %% [markdown]
# Next, we label each region of connected pixels above the threshold value. For this we use the `label` function from [dask-image ndmeasure](https://dask-image.readthedocs.io/en/latest/dask_image.ndmeasure.html). This will return both the label image, and the number of labels.

# %%
label_image, num_labels = dask_image.ndmeasure.label(threshold_image)

# %%
print("Number of labels:", int(num_labels))
plt.imshow(label_image, cmap='viridis')
# Out:
# Number of labels: 78

# %% [markdown]
# ### [Analyzing](#Analysing)

# %% [markdown]
# There are a number of inbuilt functions in [dask-image ndmeasure](https://dask-image.readthedocs.io/en/latest/dask_image.ndmeasure.html) useful for quantitative analysis.
#
# We'll use the `dask_image.ndmeasure.mean()` and `dask_image.ndmeasure.standard_deviation()` functions, and apply them to each label region with `dask_image.ndmeasure.labeled_comprehension()`.

# %%
index = list(range(int(num_labels)))  # Note that we're including the background label=0 here, too.
out_dtype = float  # The data type we want to use for our results.
default = None     # The value to return if an element of index does not exist in the label image.
mean_values = dask_image.ndmeasure.labeled_comprehension(combined_image, label_image, index, dask_image.ndmeasure.mean, out_dtype, default, pass_positions=False)
print(mean_values.compute())
# Out:
# [ 90.87492186 194.69185981 207.76964212 215.16959146 196.92609412
#  206.50032105 217.0948     211.0477766  205.68146    208.61031956
#  212.43803803 201.39967857 210.291275   198.3529809  201.21037636
#  214.13041176 200.9344975  201.85547778 194.46485714 202.60302231
#  205.20927983 203.72510602 205.94798756 205.88514047 207.33728
#  216.13305227 206.7058     211.6957     211.75921279 224.71301613
#  249.08085    215.87763779 198.27655577 213.67658483 205.65810758
#  197.46586082 202.35786579 199.16034783 216.27194848 200.69137594
#  220.99142573 207.66165    234.37771667 224.00188182 229.2705
#  232.9163     187.1873     236.16183793 223.7469     187.813475
#  227.4778     244.17155    225.49225806 239.4951     218.7795
#  242.99015132 232.4975218  201.98308947 230.57158889 212.82135217
#  242.21528571 241.32428889 228.722932   220.1454     239.55
#  246.5        241.53348    236.28736    244.84466624 242.09528
#  203.37236667 209.34061875 213.76621346 247.53468249 252.488826
#  208.5659     197.72356    203.13211   ]

# %% [markdown]
# Since we're including label 0 in our index, it's not surprising that the first mean value is so much lower than the others - it's the background region below our cutoff threshold for segmentation.

# %% [markdown]
# Let's also calculate the standard deviation of the pixel values in our greyscale image.

# %%
stdev_values = dask_image.ndmeasure.labeled_comprehension(combined_image, label_image, index, dask_image.ndmeasure.standard_deviation, out_dtype, default, pass_positions=False)

# %% [markdown]
# Finally, let's load our analysis results into a pandas table and then save it as a csv file.

# %%
import pandas as pd

df = pd.DataFrame()
df['label'] = index
df['mean'] = mean_values.compute()
df['standard_deviation'] = stdev_values.compute()

df.head()
# Out:
#    label        mean  standard_deviation
# 0      0   90.874922           65.452828
# 1      1  194.691860            2.921235
# 2      2  207.769642           11.411058
# 3      3  215.169591            9.193374
# 4      4  196.926094            5.215053

# %%
df.to_csv('example_analysis_results.csv')
print('Saved example_analysis_results.csv')
# Out:
# Saved example_analysis_results.csv

# %% [markdown]
# # Getting some Metadata from the Dask Cluster

# %%
#Task Stream
client.get_task_stream()
# Out:
# ({'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 72,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276826.4044256,
#     'stop': 1701276826.404436},),
#   'key': "('array-41806aefc4124ec1009a0c9eec354264', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276826.3999043,
#     'stop': 1701276826.4000814},),
#   'key': "('block-info-_map_read_frame-5d9d1a41aaca577bb4201a8a8588c3c4', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 786432,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276827.3680239,
#     'stop': 1701276827.3717165,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276827.3724725,
#     'stop': 1701276827.3987234}),
#   'key': "('map_read_frame-getitem-123afeeff59086d3ebaae0ac89342105', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 786432,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276827.4060931,
#     'stop': 1701276827.406107},),
#   'key': "('getitem-123afeeff59086d3ebaae0ac89342105', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.1931465,
#     'stop': 1701276828.1933732},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.1879232,
#     'stop': 1701276828.1879349},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276828.197864,
#     'stop': 1701276828.1993594,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276828.200369,
#     'stop': 1701276828.2176697}),
#   'key': "('map_read_frame-getitem-11e0198bfe7c2c7eb7e731de1903a73e', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.2206326,
#     'stop': 1701276828.2206433},),
#   'key': "('getitem-11e0198bfe7c2c7eb7e731de1903a73e', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.2420902,
#     'stop': 1701276828.2421},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.249746,
#     'stop': 1701276828.2499413},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 1, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276828.253833,
#     'stop': 1701276828.2552214,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276828.2563057,
#     'stop': 1701276828.2651975}),
#   'key': "('map_read_frame-getitem-f14d35be6ee7d8083a5c82d3cdc95d18', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.269612,
#     'stop': 1701276828.2696233},),
#   'key': "('getitem-f14d35be6ee7d8083a5c82d3cdc95d18', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.2852151,
#     'stop': 1701276828.2852304},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 2)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.29293,
#     'stop': 1701276828.2931108},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276828.2984772,
#     'stop': 1701276828.3001375,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276828.300982,
#     'stop': 1701276828.3107738}),
#   'key': "('map_read_frame-getitem-b5c6d89f0346c3f108110a0375b81a73', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.3174381,
#     'stop': 1701276828.317451},),
#   'key': "('getitem-b5c6d89f0346c3f108110a0375b81a73', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.3278556,
#     'stop': 1701276828.327871},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 3)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.334671,
#     'stop': 1701276828.334831},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276828.3400354,
#     'stop': 1701276828.341701,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276828.342958,
#     'stop': 1701276828.3508506}),
#   'key': "('map_read_frame-getitem-9f5e01a01dd73d9bb895d992ef6fed55', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276828.3583524,
#     'stop': 1701276828.358368},),
#   'key': "('getitem-9f5e01a01dd73d9bb895d992ef6fed55', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 72,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.253659,
#     'stop': 1701276829.2536674},),
#   'key': "('array-41806aefc4124ec1009a0c9eec354264', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.253044,
#     'stop': 1701276829.2532346},),
#   'key': "('block-info-_map_read_frame-5d9d1a41aaca577bb4201a8a8588c3c4', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 786432,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276829.2582686,
#     'stop': 1701276829.2594566,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276829.2600958,
#     'stop': 1701276829.2784534}),
#   'key': "('map_read_frame-getitem-123afeeff59086d3ebaae0ac89342105', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 786432,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.2828162,
#     'stop': 1701276829.2828352},),
#   'key': "('getitem-123afeeff59086d3ebaae0ac89342105', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 72,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3087223,
#     'stop': 1701276829.3087401},),
#   'key': "('array-41806aefc4124ec1009a0c9eec354264', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.253044,
#     'stop': 1701276829.2532346},
#    {'action': 'compute',
#     'start': 1701276829.3085036,
#     'stop': 1701276829.3086612}),
#   'key': "('block-info-_map_read_frame-5d9d1a41aaca577bb4201a8a8588c3c4', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 786432,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276829.3129158,
#     'stop': 1701276829.315732,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276829.3183286,
#     'stop': 1701276829.3414524}),
#   'key': "('_map_read_frame-5d9d1a41aaca577bb4201a8a8588c3c4', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 262144,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3452086,
#     'stop': 1701276829.3500137},),
#   'key': "('getitem-3158498a873f8f2042fa8032c6773194', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 262144,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3503897,
#     'stop': 1701276829.3512065},),
#   'key': "('getitem-55075714239d9792864cacc33acc6547', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 262144,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3514695,
#     'stop': 1701276829.3516095},),
#   'key': "('getitem-5ad731ffab8ad019ec89fbbb57da7a5a', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 2097152,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3548634,
#     'stop': 1701276829.361749},),
#   'key': "('add-getitem-3dedfaac3b96d60044ae92f2a1689b53', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 2097152,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.3640878,
#     'stop': 1701276829.364098},),
#   'key': "('getitem-3dedfaac3b96d60044ae92f2a1689b53', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.8903363,
#     'stop': 1701276829.8905313},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.8946185,
#     'stop': 1701276829.894643},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276829.8951585,
#     'stop': 1701276829.8966086,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276829.8973362,
#     'stop': 1701276829.909672}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9168377,
#     'stop': 1701276829.9169087},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9170492,
#     'stop': 1701276829.9171088},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.916982,
#     'stop': 1701276829.9172113},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9209325,
#     'stop': 1701276829.9220798},),
#   'key': "('add-getitem-d40caf4d7567c03f840719b0fcccf38b', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9285958,
#     'stop': 1701276829.928609},),
#   'key': "('getitem-d40caf4d7567c03f840719b0fcccf38b', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9543865,
#     'stop': 1701276829.9545536},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 1, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9603944,
#     'stop': 1701276829.9604232},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276829.9610353,
#     'stop': 1701276829.9627914,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276829.963522,
#     'stop': 1701276829.9733348}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 1, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.97786,
#     'stop': 1701276829.9779615},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9780123,
#     'stop': 1701276829.9781036},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.9781368,
#     'stop': 1701276829.9782145},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.984026,
#     'stop': 1701276829.9856393},),
#   'key': "('add-getitem-b555c841e665c9c39d7a7ce3134653da', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276829.989944,
#     'stop': 1701276829.9899597},),
#   'key': "('getitem-b555c841e665c9c39d7a7ce3134653da', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.019444,
#     'stop': 1701276830.019463},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 2)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0186718,
#     'stop': 1701276830.0188513},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276830.0234041,
#     'stop': 1701276830.0253363,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276830.0262094,
#     'stop': 1701276830.0395074}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0437894,
#     'stop': 1701276830.043862},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0439138,
#     'stop': 1701276830.0439527},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0439832,
#     'stop': 1701276830.0440195},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0490007,
#     'stop': 1701276830.0502756},),
#   'key': "('add-getitem-b217b77d9c21b3d49a81c8202f4b1caf', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0546646,
#     'stop': 1701276830.054676},),
#   'key': "('getitem-b217b77d9c21b3d49a81c8202f4b1caf', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0861914,
#     'stop': 1701276830.0862083},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 3)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.0870926,
#     'stop': 1701276830.0872684},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276830.092097,
#     'stop': 1701276830.0963469,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276830.097127,
#     'stop': 1701276830.1056516}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.1094913,
#     'stop': 1701276830.109677},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.1095223,
#     'stop': 1701276830.1097167},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.1094282,
#     'stop': 1701276830.1097474},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.1155636,
#     'stop': 1701276830.1164753},),
#   'key': "('add-getitem-b7ea0f8c09f191bd9e848b464d38e145', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.1210887,
#     'stop': 1701276830.1211076},),
#   'key': "('getitem-b7ea0f8c09f191bd9e848b464d38e145', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.4936337,
#     'stop': 1701276830.49382},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 140446412031552,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.4986045,
#     'stop': 1701276830.4987764},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 1, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 139817694262848,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.5038111,
#     'stop': 1701276830.5038357},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139817694262848,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.5044491,
#     'stop': 1701276830.5046344},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'disk-read',
#     'start': 1701276830.4920123,
#     'stop': 1701276830.498151},
#    {'action': 'compute',
#     'start': 1701276830.5097258,
#     'stop': 1701276830.5097485}),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.509812,
#     'stop': 1701276830.5098197},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 2)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.5098648,
#     'stop': 1701276830.5098715},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 3)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276830.5184526,
#     'stop': 1701276830.5186574},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 140445799675456,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276831.5251186,
#     'stop': 1701276831.5616665,
#     'source': 'tcp://127.0.0.1:38683'},
#    {'action': 'compute',
#     'start': 1701276831.5633173,
#     'stop': 1701276831.5863094}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 1, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140446412031552,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.5898638,
#     'stop': 1701276831.5899658},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140446412031552,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6005669,
#     'stop': 1701276831.6006932},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140446412031552,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6007407,
#     'stop': 1701276831.6008224},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 1, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 140445791282752,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6050086,
#     'stop': 1701276831.6068766},),
#   'key': "('add-getitem-concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 140446412031552,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6129444,
#     'stop': 1701276831.6129534},),
#   'key': "('concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276830.5179825,
#     'stop': 1701276831.6817448,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276831.6846752,
#     'stop': 1701276831.6929}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6961145,
#     'stop': 1701276831.6961892},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6962335,
#     'stop': 1701276831.6962698},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.696296,
#     'stop': 1701276831.6963308},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276831.5551074,
#     'stop': 1701276831.6860402,
#     'source': 'tcp://127.0.0.1:33107'},
#    {'action': 'compute',
#     'start': 1701276831.687047,
#     'stop': 1701276831.7044811}),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7091022,
#     'stop': 1701276831.7100356},),
#   'key': "('add-getitem-concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 196608,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.6942573,
#     'stop': 1701276831.7128122},),
#   'key': "('_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817685870144,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7128482,
#     'stop': 1701276831.7129545},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817685870144,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7130287,
#     'stop': 1701276831.7131295},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817685870144,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7131643,
#     'stop': 1701276831.7132387},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 2, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7201722,
#     'stop': 1701276831.720184},),
#   'key': "('concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139817685870144,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7233255,
#     'stop': 1701276831.7248735},),
#   'key': "('add-getitem-concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7202194,
#     'stop': 1701276831.720327},),
#   'key': "('getitem-414b582e867649843c9d0125b26a2270', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7203822,
#     'stop': 1701276831.725571},),
#   'key': "('getitem-680d331a2fc8bb908fb3e4b9bcf17201', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.726407,
#     'stop': 1701276831.726506},),
#   'key': "('getitem-a246c49eb87679f76116f3b8d5726bf4', 3, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 139817694262848,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7277565,
#     'stop': 1701276831.7277653},),
#   'key': "('concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.731794,
#     'stop': 1701276831.7333887},),
#   'key': "('add-getitem-concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 524288,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276831.7407606,
#     'stop': 1701276831.7407727},),
#   'key': "('concatenate-53d3d6b8f1a5fc013321b27519d26e3e', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3643522,
#     'stop': 1701276832.3643694},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 0)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021725644352,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3644342,
#     'stop': 1701276832.3644445},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 2)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 140021717251648,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3645008,
#     'stop': 1701276832.3645122},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 3)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3308,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3628376,
#     'stop': 1701276832.3630161},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 0, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3088,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.363078,
#     'stop': 1701276832.36322},),
#   'key': "('block-info-_trim-4ac6d84515bab3f79ff57be4366d286c', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 3120,
#   'thread': 139699605730880,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3632557,
#     'stop': 1701276832.3633966},),
#   'key': "('block-info-_trim-4ac6d84515bab3f79ff57be4366d286c', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:33107',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 140021235447360,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3659003,
#     'stop': 1701276832.3660574},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 3, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 92,
#   'thread': 139817685870144,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3965907,
#     'stop': 1701276832.3966033},),
#   'key': "('array-4079046d5b1c2fbf2f58af159ec49ccd', 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 139817694262848,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.3966713,
#     'stop': 1701276832.3968432},),
#   'key': "('block-info-_map_read_frame-12e8709b1d126a7f153df27a046b0a2c', 2, 0, 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 3104,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x08builtins\x94\x8c\x04dict\x94\x93\x94.',
#   'typename': 'dict',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276832.396899,
#     'stop': 1701276832.3970523},),
#   'key': "('block-info-_trim-4ac6d84515bab3f79ff57be4366d286c', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:42735',
#   'status': 'OK',
#   'nbytes': 3324,
#   'thread': 140445791282752,
# ...
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.097608,
#     'stop': 1701276837.098841},),
#   'key': "('eq-475f7c1d581dce5876d068397c1e3084', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.099687,
#     'stop': 1701276837.0997458},),
#   'key': "('eq-82e0c8df4cdf663a1f89839865bf9405', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.099768,
#     'stop': 1701276837.0998085},),
#   'key': "('eq-82e0c8df4cdf663a1f89839865bf9405', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1001117,
#     'stop': 1701276837.1001616},),
#   'key': "('eq-82e0c8df4cdf663a1f89839865bf9405', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.100513,
#     'stop': 1701276837.100563},),
#   'key': "('eq-60cf7f746170994a6e07595b64cbda79', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1005828,
#     'stop': 1701276837.1006224},),
#   'key': "('eq-60cf7f746170994a6e07595b64cbda79', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.100912,
#     'stop': 1701276837.100959},),
#   'key': "('eq-60cf7f746170994a6e07595b64cbda79', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1850302,
#     'stop': 1701276837.1851704},),
#   'key': "('eq-6da853892bd7ee59c4e194b11b109ddc', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1852283,
#     'stop': 1701276837.1853373},),
#   'key': "('eq-6da853892bd7ee59c4e194b11b109ddc', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1853702,
#     'stop': 1701276837.1854727},),
#   'key': "('eq-b022576ab120856e0d297f859b974468', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.101348,
#     'stop': 1701276837.1013951},),
#   'key': "('eq-60cf7f746170994a6e07595b64cbda79', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1014156,
#     'stop': 1701276837.1014588},),
#   'key': "('eq-f26089856c0ff461a31e8dd3b14d9761', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'transfer',
#     'start': 1701276837.0784218,
#     'stop': 1701276837.0913267,
#     'source': 'tcp://127.0.0.1:38683'},
#    {'action': 'compute',
#     'start': 1701276837.1021428,
#     'stop': 1701276837.102189}),
#   'key': "('eq-f26089856c0ff461a31e8dd3b14d9761', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1024795,
#     'stop': 1701276837.1025238},),
#   'key': "('eq-f26089856c0ff461a31e8dd3b14d9761', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1025422,
#     'stop': 1701276837.1025767},),
#   'key': "('eq-f26089856c0ff461a31e8dd3b14d9761', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.102904,
#     'stop': 1701276837.1029534},),
#   'key': "('eq-ef437b643c257b4368c2dcbb077605d4', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1032524,
#     'stop': 1701276837.103299},),
#   'key': "('eq-ef437b643c257b4368c2dcbb077605d4', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.103317,
#     'stop': 1701276837.1033537},),
#   'key': "('eq-ef437b643c257b4368c2dcbb077605d4', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 32768,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.188214,
#     'stop': 1701276837.1882558},),
#   'key': "('rechunk-split-b5b6801b3dd357064ffe9b6e1b766f04', 1)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 32768,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.188304,
#     'stop': 1701276837.188341},),
#   'key': "('rechunk-split-b5b6801b3dd357064ffe9b6e1b766f04', 3)"},
#  {'worker': 'tcp://127.0.0.1:38683',
#   'status': 'OK',
#   'nbytes': 32768,
#   'thread': 139817517053504,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1883714,
#     'stop': 1701276837.1883903},),
#   'key': "('rechunk-split-b5b6801b3dd357064ffe9b6e1b766f04', 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1036713,
#     'stop': 1701276837.1037164},),
#   'key': "('eq-ef437b643c257b4368c2dcbb077605d4', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1045113,
#     'stop': 1701276837.1045628},),
#   'key': "('eq-b9f0960a88885a359c3e380a4bcf9033', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1045814,
#     'stop': 1701276837.1046202},),
#   'key': "('eq-b9f0960a88885a359c3e380a4bcf9033', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1049004,
#     'stop': 1701276837.1049435},),
#   'key': "('eq-b9f0960a88885a359c3e380a4bcf9033', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1052742,
#     'stop': 1701276837.1053221},),
#   'key': "('eq-b9f0960a88885a359c3e380a4bcf9033', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1053414,
#     'stop': 1701276837.1053798},),
#   'key': "('eq-cce66c0a490961ccfe1f3ee21ce9e666', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1056604,
#     'stop': 1701276837.1057048},),
#   'key': "('eq-cce66c0a490961ccfe1f3ee21ce9e666', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.106044,
#     'stop': 1701276837.1060917},),
#   'key': "('eq-cce66c0a490961ccfe1f3ee21ce9e666', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1061113,
#     'stop': 1701276837.1061502},),
#   'key': "('eq-cce66c0a490961ccfe1f3ee21ce9e666', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1069643,
#     'stop': 1701276837.107033},),
#   'key': "('eq-c56c1820ea42a702b82b8c0c17eeb021', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1074154,
#     'stop': 1701276837.1074765},),
#   'key': "('eq-c56c1820ea42a702b82b8c0c17eeb021', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1074975,
#     'stop': 1701276837.1075602},),
#   'key': "('eq-c56c1820ea42a702b82b8c0c17eeb021', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1078737,
#     'stop': 1701276837.107947},),
#   'key': "('eq-c56c1820ea42a702b82b8c0c17eeb021', 0, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.10843,
#     'stop': 1701276837.1084845},),
#   'key': "('eq-b0f9a73107696ab04d9fe1a9abdb3951', 1, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1085043,
#     'stop': 1701276837.1085458},),
#   'key': "('eq-b0f9a73107696ab04d9fe1a9abdb3951', 1, 0)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 65536,
#   'thread': 139699842704960,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1103733,
#     'stop': 1701276837.1104422},),
#   'key': "('eq-b0f9a73107696ab04d9fe1a9abdb3951', 0, 1)"},
#  {'worker': 'tcp://127.0.0.1:37993',
#   'status': 'OK',
#   'nbytes': 32768,
#   'thread': 139699597338176,
#   'type': b'\x80\x04\x95\x15\x00\x00\x00\x00\x00\x00\x00\x8c\x05numpy\x94\x8c\x07ndarray\x94\x93\x94.',
#   'typename': 'numpy.ndarray',
#   'metadata': {},
#   'startstops': ({'action': 'compute',
#     'start': 1701276837.1108785,
#     'stop': 1701276837.1108992},),
#   'key': "('rechunk-split-4cb3f185ee6237405b1fbe8770bee23c', 4)"},
#  ...)

# %%
# Scheduler logs
client.get_scheduler_logs()
# Out:
# (('INFO', 'distributed.scheduler - INFO - Clear task state'),
#  ('INFO',
#   'distributed.scheduler - INFO -   Scheduler at:     tcp://127.0.0.1:41349'),
#  ('INFO',
#   'distributed.scheduler - INFO -   dashboard at:            127.0.0.1:8787'),
#  ('INFO',
#   "distributed.scheduler - INFO - Register worker <WorkerState 'tcp://127.0.0.1:37993', name: 0, status: running, memory: 0, processing: 0>"),
#  ('INFO',
#   'distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:37993'),
#  ('INFO',
#   "distributed.scheduler - INFO - Register worker <WorkerState 'tcp://127.0.0.1:38683', name: 1, status: running, memory: 0, processing: 0>"),
#  ('INFO',
#   'distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:38683'),
#  ('INFO',
#   "distributed.scheduler - INFO - Register worker <WorkerState 'tcp://127.0.0.1:42735', name: 2, status: running, memory: 0, processing: 0>"),
#  ('INFO',
#   'distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:42735'),
#  ('INFO',
#   "distributed.scheduler - INFO - Register worker <WorkerState 'tcp://127.0.0.1:33107', name: 3, status: running, memory: 0, processing: 0>"),
#  ('INFO',
#   'distributed.scheduler - INFO - Starting worker compute stream, tcp://127.0.0.1:33107'),
#  ('INFO',
#   'distributed.scheduler - INFO - Receive client connection: Client-cdd11c3a-8ed7-11ee-916e-10f60a690f05'),
#  ('INFO',
#   'distributed.scheduler - INFO - Receive client connection: Client-worker-e2fb59c5-8ed7-11ee-919a-10f60a690f05'),
#  ('INFO',
#   'distributed.scheduler - INFO - Receive client connection: Client-worker-e3019d3f-8ed7-11ee-91a0-10f60a690f05'),
#  ('INFO',
#   'distributed.scheduler - INFO - Receive client connection: Client-worker-e304a956-8ed7-11ee-919e-10f60a690f05'),
#  ('INFO',
#   'distributed.scheduler - INFO - Receive client connection: Client-worker-e301f146-8ed7-11ee-9198-10f60a690f05'))

# %%
# Worker infos
client.get_worker_logs()
# Out:
# {'tcp://127.0.0.1:33107': (('INFO',
#    'distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:33107'),
#   ('INFO',
#    'distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:33107'),
#   ('INFO',
#    'distributed.worker - INFO -          dashboard at:            127.0.0.1:35673'),
#   ('INFO',
#    'distributed.worker - INFO - Waiting to connect to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -               Threads:                          3'),
#   ('INFO',
#    'distributed.worker - INFO -                Memory:                   7.75 GiB'),
#   ('INFO',
#    'distributed.worker - INFO -       Local Directory: /home/agueroudji/recup/dask-worker-space/worker-v8687kxj'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -         Registered to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------')),
#  'tcp://127.0.0.1:37993': (('INFO',
#    'distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:37993'),
#   ('INFO',
#    'distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:37993'),
#   ('INFO',
#    'distributed.worker - INFO -          dashboard at:            127.0.0.1:36141'),
#   ('INFO',
#    'distributed.worker - INFO - Waiting to connect to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -               Threads:                          3'),
#   ('INFO',
#    'distributed.worker - INFO -                Memory:                   7.75 GiB'),
#   ('INFO',
#    'distributed.worker - INFO -       Local Directory: /home/agueroudji/recup/dask-worker-space/worker-0c747cww'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -         Registered to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------')),
#  'tcp://127.0.0.1:38683': (('INFO',
#    'distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:38683'),
#   ('INFO',
#    'distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:38683'),
#   ('INFO',
#    'distributed.worker - INFO -          dashboard at:            127.0.0.1:46375'),
#   ('INFO',
#    'distributed.worker - INFO - Waiting to connect to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -               Threads:                          3'),
#   ('INFO',
#    'distributed.worker - INFO -                Memory:                   7.75 GiB'),
#   ('INFO',
#    'distributed.worker - INFO -       Local Directory: /home/agueroudji/recup/dask-worker-space/worker-ksqedda4'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -         Registered to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------')),
#  'tcp://127.0.0.1:42735': (('INFO',
#    'distributed.worker - INFO -       Start worker at:      tcp://127.0.0.1:42735'),
#   ('INFO',
#    'distributed.worker - INFO -          Listening to:      tcp://127.0.0.1:42735'),
#   ('INFO',
#    'distributed.worker - INFO -          dashboard at:            127.0.0.1:39265'),
#   ('INFO',
#    'distributed.worker - INFO - Waiting to connect to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -               Threads:                          3'),
#   ('INFO',
#    'distributed.worker - INFO -                Memory:                   7.75 GiB'),
#   ('INFO',
#    'distributed.worker - INFO -       Local Directory: /home/agueroudji/recup/dask-worker-space/worker-p9deckpu'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'),
#   ('INFO',
#    'distributed.worker - INFO -         Registered to:      tcp://127.0.0.1:41349'),
#   ('INFO',
#    'distributed.worker - INFO - -------------------------------------------------'))}

# %%
# Cluster info 
client.scheduler_info()
# Out:
# {'type': 'Scheduler',
#  'id': 'Scheduler-e67238d6-5378-486f-abf1-42a8b2e1864d',
#  'address': 'tcp://127.0.0.1:41349',
#  'services': {'dashboard': 8787},
#  'started': 1701276801.7222748,
#  'workers': {'tcp://127.0.0.1:33107': {'type': 'Worker',
#    'id': 3,
#    'host': '127.0.0.1',
#    'resources': {},
#    'local_directory': '/home/agueroudji/recup/dask-worker-space/worker-v8687kxj',
#    'name': 3,
#    'nthreads': 3,
#    'memory_limit': 8322147328,
#    'last_seen': 1701276846.378871,
#    'services': {'dashboard': 35673},
#    'metrics': {'executing': 0,
#     'in_memory': 0,
#     'ready': 0,
#     'in_flight': 0,
#     'bandwidth': {'total': 101465912.49187686, 'workers': {}, 'types': {}},
#     'spilled_nbytes': 0,
#     'cpu': 48.6,
#     'memory': 214376448,
#     'time': 1701276845.876689,
#     'read_bytes': 8800309.543039368,
#     'write_bytes': 8800309.543039368,
#     'read_bytes_disk': 0.0,
#     'write_bytes_disk': 0.0,
#     'num_fds': 42},
#    'nanny': 'tcp://127.0.0.1:37385'},
#   'tcp://127.0.0.1:37993': {'type': 'Worker',
#    'id': 0,
#    'host': '127.0.0.1',
#    'resources': {},
#    'local_directory': '/home/agueroudji/recup/dask-worker-space/worker-0c747cww',
#    'name': 0,
#    'nthreads': 3,
#    'memory_limit': 8322147328,
#    'last_seen': 1701276846.623697,
#    'services': {'dashboard': 36141},
#    'metrics': {'executing': 0,
#     'in_memory': 0,
#     'ready': 0,
#     'in_flight': 0,
#     'bandwidth': {'total': 97217230.02437218, 'workers': {}, 'types': {}},
#     'spilled_nbytes': 0,
#     'cpu': 30.0,
#     'memory': 224985088,
#     'time': 1701276846.07772,
#     'read_bytes': 6471494.224112722,
#     'write_bytes': 6471494.224112722,
#     'read_bytes_disk': 0.0,
#     'write_bytes_disk': 164069.85326236955,
#     'num_fds': 41},
#    'nanny': 'tcp://127.0.0.1:36393'},
#   'tcp://127.0.0.1:38683': {'type': 'Worker',
#    'id': 1,
#    'host': '127.0.0.1',
#    'resources': {},
#    'local_directory': '/home/agueroudji/recup/dask-worker-space/worker-ksqedda4',
#    'name': 1,
#    'nthreads': 3,
#    'memory_limit': 8322147328,
#    'last_seen': 1701276846.6245153,
#    'services': {'dashboard': 46375},
#    'metrics': {'executing': 0,
#     'in_memory': 0,
#     'ready': 0,
#     'in_flight': 0,
#     'bandwidth': {'total': 100000000, 'workers': {}, 'types': {}},
#     'spilled_nbytes': 0,
#     'cpu': 34.5,
#     'memory': 219512832,
#     'time': 1701276846.1138232,
#     'read_bytes': 6300773.550853201,
#     'write_bytes': 6300773.550853201,
#     'read_bytes_disk': 0.0,
#     'write_bytes_disk': 166458.1323507255,
#     'num_fds': 40},
#    'nanny': 'tcp://127.0.0.1:33211'},
#   'tcp://127.0.0.1:42735': {'type': 'Worker',
#    'id': 2,
#    'host': '127.0.0.1',
#    'resources': {},
#    'local_directory': '/home/agueroudji/recup/dask-worker-space/worker-p9deckpu',
#    'name': 2,
#    'nthreads': 3,
#    'memory_limit': 8322147328,
#    'last_seen': 1701276846.3775415,
#    'services': {'dashboard': 39265},
#    'metrics': {'executing': 0,
#     'in_memory': 0,
#     'ready': 0,
#     'in_flight': 0,
#     'bandwidth': {'total': 98164843.11597146, 'workers': {}, 'types': {}},
#     'spilled_nbytes': 0,
#     'cpu': 58.0,
#     'memory': 219074560,
#     'time': 1701276845.8561583,
#     'read_bytes': 9153030.97858245,
#     'write_bytes': 9153030.97858245,
#     'read_bytes_disk': 0.0,
#     'write_bytes_disk': 0.0,
#     'num_fds': 40},
#    'nanny': 'tcp://127.0.0.1:35709'}}}

# %% [markdown]
# The Dashboard contains more data about the status of the cluster, taskstream, its distribution, the system...

# %% [markdown]
# ## [Next steps](#Next-steps)

# %% [markdown]
# I hope this guide has helped you to get started with dask-image.
#
# **Documentation**
#
# You can read more about dask-image in the [dask-image documentation](https://dask-image.readthedocs.io/en/latest/api.html)
# and [API reference](https://dask-image.readthedocs.io/en/latest/api.html). Documentation for [dask is here](http://docs.dask.org/en/latest/).
#
# The dask-examples repository has a number of other example notebooks: https://github.com/dask/dask-examples
#
# **Scaling up with dask distributed**
#
# If you want to send dask jobs to a computing cluster for distributed processing, you should take a look at [dask distributed](https://distributed.dask.org/en/latest/). There is also a [quickstart guide available](https://distributed.dask.org/en/latest/quickstart.html).
#
# **Saving image data with zarr**
#
# In some cases it may be necessary to save large data after image processing, [zarr](https://zarr.readthedocs.io/en/stable/) is a python library that you may find useful.

# %% [markdown]
# ## [Cleaning up temporary directories and files](#Cleaning-up-temporary-directories-and-files)

# %% [markdown]
# You recall we saved some example data to the directories `temp/` and `temp-tiles/`. To delete the contents, run the following command:

# %%
# !rm -r temp

# %%
# !rm -r temp-tiles
